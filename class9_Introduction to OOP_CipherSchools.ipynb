# %%
class person:
    pass
p=person()
print(p)
hex(id(p))
# Out:
# ...
# '0x7feef06e3490'

# %%
class person:
    name="Abhiram"
    def is_class(self):
        print(f"Hi myself {self.name}")
p=person()
person.is_class(p) #function call
p.is_class() #method call
# Out:
# Hi myself Abhiram
# Hi myself Abhiram
