# %%
a=[1,2,3,4]
print(a)

# %%
b=["nishant",1,2,print]
print(b)
# Out:
# ['nishant', 1, 2, <built-in function print>]

# %%
a=[1,2,3,4,5]
a[0]=100
print(a)
# Out:
# [100, 2, 3, 4, 5]

# %%
print(len([1,2,3,4]))
# Out:
# 4

# %%
a=[1,2,3,4,5]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a=[1,2,3]
a.insert(1,100)
print(a)
# Out:
# [1, 100, 2, 3]

# %%
a=[1,2,3,4]
a.append(100)
print(a)
# Out:
# [1, 2, 3, 4, 100]

# %%
a=[1,2,3,4]
a.pop()
print(a)
# Out:
# [1, 2, 3]

# %%
a=list(map(int,input().split()))
print(a)
print(a[0])
# Out:
# 1 2 3 4
# [1, 2, 3, 4]
# 1

# %%
a=[1,2,3,4]
for x in map(lambda x:x**2 ,a):
    print(x)
# Out:
# 1
# 4
# 9
# 16
