# %%
def show_loading():
    for _ in range(3):
        print("loading...")
a=1
b=10
print(a+b)
show_loading()
print(a-b)
show_loading()
print(a*b)
show_loading()
print(a/b)
# Out:
# 11
# loading...
# loading...
# loading...
# -9
# loading...
# loading...
# loading...
# 10
# loading...
# loading...
# loading...
# 0.1

# %%
def add(a,b):
    return a+b
a=add(10,20)
print(a)
# Out:
# 30

# %%
def show_loading():
    for _ in range(3):
        print("loading","."*(_+1))
show_loading()
# Out:
# loading .
# loading ..
# loading ...

# %%
def knock(name):
    for _ in range(3):
        print("knock knock knock",name)
knock("nishant")

# %%
def knock(name,times=3):
    for _ in range(times):
        print("knock knock knock",name)
knock("nishant",100)
