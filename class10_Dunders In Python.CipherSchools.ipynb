# %%
class person:
    def __init__(self,name):
        self.name=name
    def abc(self):
        print("My name is",self.name)
p=person("abhiramt")
p.abc()
# Out:
# My name is abhiramt

# %%
class A:
    def __init__(self):
        print(self)
        print("initialized")
a=A()
# Out:
# ...
# initialized

# %%
class A:
    def __init__(self):
        print(self)
        print("initialized")
    def __del__(self):
        print("I am dying")
a=A()
del a
# Out:
# ...
# initialized
# I am dying

# %%
"abhiram".__mul__(2)
# Out:
# 'abhiramabhiram'

# %%
a=1
a.__add__(5)
